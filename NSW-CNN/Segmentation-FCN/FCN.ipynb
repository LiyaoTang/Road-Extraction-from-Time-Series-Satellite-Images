# %%
import numpy as np
import sklearn as sk
import matplotlib.pyplot as plt
import tensorflow as tf
import scipy.io as sio
import skimage.io
import h5py

import sys
sys.path.append('../Metric/')
sys.path.append('../../Visualization/')
sys.path.append('../../Data_Preprocessing/')
from Metric import *
from Data_Extractor import *
from Bilinear_Kernel import *
# Out:
# /home/admin-u6142160/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %% [markdown]
# Load & Reorder:

# %%
# Load
path_raw_image = "../../Data/090085/All_Data/090085_20170531.h5"
path_road_mask = "../../Data/090085/Road_Data/motor_trunk_pri_sec_tert_uncl_track/motor_trunk_pri_sec_tert_uncl_track.tif"
path_topleft_coordinate = "../../Data/090085/Road_Data/motor_trunk_pri_sec_tert_uncl_track/posneg_topleft_coordinate_8"

raw_image = np.array(h5py.File(path_raw_image)['scene'])
road_mask = skimage.io.imread(path_road_mask)

data = h5py.File(path_topleft_coordinate, 'r')

pos_topleft_coord = np.array(data['positive_example'])
neg_topleft_coord = np.array(data['negative_example'])
data.close()

print(raw_image.shape, road_mask.shape)
print(raw_image.min())
# Out:
# (7, 7961, 8091) (7961, 8091)
# -9999

# %%
# Construct training & test set
pos_size = pos_topleft_coord.shape[0]
neg_size = neg_topleft_coord.shape[0]

np.random.shuffle(pos_topleft_coord)
np.random.shuffle(neg_topleft_coord)

Train_Data = Data_Extractor (raw_image, road_mask, 8,
                             pos_topleft_coord = pos_topleft_coord[:int(0.75*pos_size) ,:],
                             neg_topleft_coord = neg_topleft_coord[:int(0.75*neg_size) ,:])

Test_Data  = Data_Extractor (raw_image, road_mask, 8,
                             pos_topleft_coord = pos_topleft_coord[ int(0.75*pos_size):int(0.90*pos_size),:],
                             neg_topleft_coord = neg_topleft_coord[ int(0.75*neg_size):int(0.90*neg_size),:])

print(Train_Data.size, Test_Data.size)
# Out:
# 19131279 3826257

# %% [markdown]
# Model parameters:

# %%
size = 128
band = 7

# Hyper parameters
conv_out = [0, 32, 64, 96]

class_output = 1 # number of possible classifications for the problem

# keep_rate = 0.5 # need regularization => otherwise NaN appears inside CNN

# class_weight = [Train_Data.pos_size/Train_Data.size, Train_Data.neg_size/Train_Data.size]

batch_size = 64
learning_rate = 9e-6
epoch = 15

# print(class_weight, '[neg, pos]')

# %% [markdown]
# Convolutional Layers:

# %%
tf.reset_default_graph()

with tf.variable_scope('feed'):
    x = tf.placeholder(tf.float32, shape=[None, size, size, band], name='x')
    y = tf.placeholder(tf.float32, shape=[None], name='y')

    # keep_prob = tf.placeholder(tf.float32, name='keep_prob') # dropout
    # is_training = tf.placeholder(tf.bool, name='is_training') # batch norm


with tf.variable_scope('down_sampling'):
    # Convolutional Layer 1
    net = tf.contrib.layers.conv2d(inputs=x, num_outputs=conv_out[1], kernel_size=3, 
                                   stride=1, padding='SAME', scope='conv1')

    net = tf.contrib.layers.max_pool2d(inputs=net, kernel_size=2, stride=2, padding='VALID', scope='pool1')
    pool_1 = net
    print(pool_1)
    
    # Convolutional Layer 2
    net = tf.contrib.layers.conv2d(inputs=net, num_outputs=conv_out[2], kernel_size=3, 
                                   stride=1, padding='SAME', scope='conv2')

    net = tf.contrib.layers.max_pool2d(inputs=net, kernel_size=2, stride=2, padding='VALID', scope='pool2')
    pool_2 = net
    print(pool_2)
    
    # Convolutional Layer 3
    net = tf.contrib.layers.conv2d(inputs=net, num_outputs=conv_out[3], kernel_size=3, 
                                   stride=1, padding='SAME', scope='conv3')

    net = tf.contrib.layers.max_pool2d(inputs=net, kernel_size=2, stride=2, padding='VALID', scope='pool3')

with tf.variable_scope('up_sampling'):
    net = tf.contrib.layers.conv2d_transpose(inputs=net, num_outputs=None, kernel_size=(3, 3), stride=2, 
                                             weights_initializer=get_bilinear_upsample_weights(2, conv_out[2]), 
                                             scope='conv3_T')
    print(net)
    with tf.variable_scope('fuse_1'):
        net = net + pool_2
        
    net = tf.contrib.layers.conv2d_transpose(inputs=net, num_outputs=conv_out[1], kernel_size=3, stride=2, 
                                             weights_initializer=get_bilinear_upsample_weights(2, conv_out[1]), 
                                             scope='conv2_T')
    
    net = tf.contrib.layers.conv2d_transpose(inputs=net, num_outputs=class_output, kernel_size=3, stride=2, 
                                             weights_initializer=get_bilinear_upsample_weights(2, class_output), 
                                             scope='conv1_T')
# Out:
# /home/admin-u6142160/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/tf_inspect.py:45: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if d.decorator_argspec is not None), _inspect.getargspec(target))
# /home/admin-u6142160/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/tf_inspect.py:45: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if d.decorator_argspec is not None), _inspect.getargspec(target))
# /home/admin-u6142160/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/tf_inspect.py:45: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if d.decorator_argspec is not None), _inspect.getargspec(target))
# /home/admin-u6142160/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/tf_inspect.py:45: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if d.decorator_argspec is not None), _inspect.getargspec(target))
# /home/admin-u6142160/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/tf_inspect.py:45: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if d.decorator_argspec is not None), _inspect.getargspec(target))
# /home/admin-u6142160/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/tf_inspect.py:45: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if d.decorator_argspec is not None), _inspect.getargspec(target))
# /home/admin-u6142160/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/tf_inspect.py:45: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if d.decorator_argspec is not None), _inspect.getargspec(target))
# /home/admin-u6142160/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/tf_inspect.py:45: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if d.decorator_argspec is not None), _inspect.getargspec(target))
# /home/admin-u6142160/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/tf_inspect.py:45: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if d.decorator_argspec is not None), _inspect.getargspec(target))
# /home/admin-u6142160/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/tf_inspect.py:45: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if d.decorator_argspec is not None), _inspect.getargspec(target))
# /home/admin-u6142160/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/tf_inspect.py:45: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if d.decorator_argspec is not None), _inspect.getargspec(target))
# /home/admin-u6142160/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/tf_inspect.py:45: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if d.decorator_argspec is not None), _inspect.getargspec(target))
# /home/admin-u6142160/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/tf_inspect.py:45: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if d.decorator_argspec is not None), _inspect.getargspec(target))
# /home/admin-u6142160/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/tf_inspect.py:45: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if d.decorator_argspec is not None), _inspect.getargspec(target))
# /home/admin-u6142160/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/tf_inspect.py:45: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if d.decorator_argspec is not None), _inspect.getargspec(target))
# /home/admin-u6142160/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/tf_inspect.py:45: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if d.decorator_argspec is not None), _inspect.getargspec(target))
# /home/admin-u6142160/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/tf_inspect.py:45: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if d.decorator_argspec is not None), _inspect.getargspec(target))
# /home/admin-u6142160/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/tf_inspect.py:45: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if d.decorator_argspec is not None), _inspect.getargspec(target))
# /home/admin-u6142160/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/tf_inspect.py:45: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if d.decorator_argspec is not None), _inspect.getargspec(target))
# /home/admin-u6142160/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/tf_inspect.py:45: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if d.decorator_argspec is not None), _inspect.getargspec(target))
# /home/admin-u6142160/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/tf_inspect.py:45: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if d.decorator_argspec is not None), _inspect.getargspec(target))
# /home/admin-u6142160/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/tf_inspect.py:45: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if d.decorator_argspec is not None), _inspect.getargspec(target))
# /home/admin-u6142160/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/tf_inspect.py:45: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if d.decorator_argspec is not None), _inspect.getargspec(target))
# /home/admin-u6142160/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/tf_inspect.py:45: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if d.decorator_argspec is not None), _inspect.getargspec(target))
# /home/admin-u6142160/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/tf_inspect.py:45: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if d.decorator_argspec is not None), _inspect.getargspec(target))
# /home/admin-u6142160/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/tf_inspect.py:45: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if d.decorator_argspec is not None), _inspect.getargspec(target))
# /home/admin-u6142160/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/tf_inspect.py:45: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if d.decorator_argspec is not None), _inspect.getargspec(target))
# /home/admin-u6142160/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/tf_inspect.py:45: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if d.decorator_argspec is not None), _inspect.getargspec(target))
# /home/admin-u6142160/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/tf_inspect.py:45: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if d.decorator_argspec is not None), _inspect.getargspec(target))
# /home/admin-u6142160/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/tf_inspect.py:45: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if d.decorator_argspec is not None), _inspect.getargspec(target))
# /home/admin-u6142160/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/tf_inspect.py:45: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if d.decorator_argspec is not None), _inspect.getargspec(target))
# /home/admin-u6142160/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/tf_inspect.py:45: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if d.decorator_argspec is not None), _inspect.getargspec(target))
# /home/admin-u6142160/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/tf_inspect.py:45: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if d.decorator_argspec is not None), _inspect.getargspec(target))
# /home/admin-u6142160/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/tf_inspect.py:45: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if d.decorator_argspec is not None), _inspect.getargspec(target))
# /home/admin-u6142160/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/tf_inspect.py:45: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if d.decorator_argspec is not None), _inspect.getargspec(target))
# /home/admin-u6142160/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/tf_inspect.py:45: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if d.decorator_argspec is not None), _inspect.getargspec(target))
# /home/admin-u6142160/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/tf_inspect.py:45: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if d.decorator_argspec is not None), _inspect.getargspec(target))
# /home/admin-u6142160/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/tf_inspect.py:45: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if d.decorator_argspec is not None), _inspect.getargspec(target))
# /home/admin-u6142160/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/tf_inspect.py:45: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if d.decorator_argspec is not None), _inspect.getargspec(target))
# /home/admin-u6142160/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/tf_inspect.py:45: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if d.decorator_argspec is not None), _inspect.getargspec(target))
# /home/admin-u6142160/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/tf_inspect.py:45: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if d.decorator_argspec is not None), _inspect.getargspec(target))
# /home/admin-u6142160/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/tf_inspect.py:45: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if d.decorator_argspec is not None), _inspect.getargspec(target))
# /home/admin-u6142160/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/tf_inspect.py:45: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if d.decorator_argspec is not None), _inspect.getargspec(target))
# /home/admin-u6142160/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/tf_inspect.py:45: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if d.decorator_argspec is not None), _inspect.getargspec(target))
# /home/admin-u6142160/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/tf_inspect.py:45: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if d.decorator_argspec is not None), _inspect.getargspec(target))
# /home/admin-u6142160/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/tf_inspect.py:45: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if d.decorator_argspec is not None), _inspect.getargspec(target))
# /home/admin-u6142160/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/tf_inspect.py:45: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if d.decorator_argspec is not None), _inspect.getargspec(target))
# /home/admin-u6142160/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/tf_inspect.py:45: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if d.decorator_argspec is not None), _inspect.getargspec(target))
# /home/admin-u6142160/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/tf_inspect.py:45: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if d.decorator_argspec is not None), _inspect.getargspec(target))
# /home/admin-u6142160/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/tf_inspect.py:45: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if d.decorator_argspec is not None), _inspect.getargspec(target))
# /home/admin-u6142160/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/tf_inspect.py:45: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if d.decorator_argspec is not None), _inspect.getargspec(target))
# /home/admin-u6142160/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/tf_inspect.py:45: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if d.decorator_argspec is not None), _inspect.getargspec(target))
# /home/admin-u6142160/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/tf_inspect.py:45: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if d.decorator_argspec is not None), _inspect.getargspec(target))
# /home/admin-u6142160/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/tf_inspect.py:45: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if d.decorator_argspec is not None), _inspect.getargspec(target))
# /home/admin-u6142160/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/tf_inspect.py:45: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if d.decorator_argspec is not None), _inspect.getargspec(target))
# /home/admin-u6142160/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/tf_inspect.py:45: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if d.decorator_argspec is not None), _inspect.getargspec(target))
# /home/admin-u6142160/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/tf_inspect.py:45: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if d.decorator_argspec is not None), _inspect.getargspec(target))
# /home/admin-u6142160/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/tf_inspect.py:45: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if d.decorator_argspec is not None), _inspect.getargspec(target))
# /home/admin-u6142160/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/tf_inspect.py:45: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if d.decorator_argspec is not None), _inspect.getargspec(target))
# /home/admin-u6142160/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/tf_inspect.py:45: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if d.decorator_argspec is not None), _inspect.getargspec(target))
# /home/admin-u6142160/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/tf_inspect.py:45: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if d.decorator_argspec is not None), _inspect.getargspec(target))
# /home/admin-u6142160/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/tf_inspect.py:45: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if d.decorator_argspec is not None), _inspect.getargspec(target))
# /home/admin-u6142160/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/tf_inspect.py:45: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if d.decorator_argspec is not None), _inspect.getargspec(target))
# /home/admin-u6142160/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/tf_inspect.py:45: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if d.decorator_argspec is not None), _inspect.getargspec(target))
# /home/admin-u6142160/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/tf_inspect.py:45: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if d.decorator_argspec is not None), _inspect.getargspec(target))
# /home/admin-u6142160/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/tf_inspect.py:45: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if d.decorator_argspec is not None), _inspect.getargspec(target))
# /home/admin-u6142160/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/tf_inspect.py:45: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if d.decorator_argspec is not None), _inspect.getargspec(target))
# /home/admin-u6142160/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/tf_inspect.py:45: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if d.decorator_argspec is not None), _inspect.getargspec(target))
# /home/admin-u6142160/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/tf_inspect.py:45: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if d.decorator_argspec is not None), _inspect.getargspec(target))
# /home/admin-u6142160/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/tf_inspect.py:45: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if d.decorator_argspec is not None), _inspect.getargspec(target))
# /home/admin-u6142160/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/tf_inspect.py:45: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if d.decorator_argspec is not None), _inspect.getargspec(target))
# /home/admin-u6142160/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/tf_inspect.py:45: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if d.decorator_argspec is not None), _inspect.getargspec(target))
# /home/admin-u6142160/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/tf_inspect.py:45: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if d.decorator_argspec is not None), _inspect.getargspec(target))
# /home/admin-u6142160/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/tf_inspect.py:45: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if d.decorator_argspec is not None), _inspect.getargspec(target))
# /home/admin-u6142160/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/tf_inspect.py:45: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if d.decorator_argspec is not None), _inspect.getargspec(target))
# /home/admin-u6142160/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/tf_inspect.py:45: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if d.decorator_argspec is not None), _inspect.getargspec(target))
# /home/admin-u6142160/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/tf_inspect.py:45: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if d.decorator_argspec is not None), _inspect.getargspec(target))
# /home/admin-u6142160/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/tf_inspect.py:45: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if d.decorator_argspec is not None), _inspect.getargspec(target))
# /home/admin-u6142160/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/tf_inspect.py:45: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if d.decorator_argspec is not None), _inspect.getargspec(target))
# /home/admin-u6142160/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/tf_inspect.py:45: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if d.decorator_argspec is not None), _inspect.getargspec(target))
# /home/admin-u6142160/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/tf_inspect.py:45: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if d.decorator_argspec is not None), _inspect.getargspec(target))
# /home/admin-u6142160/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/tf_inspect.py:45: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if d.decorator_argspec is not None), _inspect.getargspec(target))
# /home/admin-u6142160/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/tf_inspect.py:45: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if d.decorator_argspec is not None), _inspect.getargspec(target))
# /home/admin-u6142160/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/tf_inspect.py:45: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if d.decorator_argspec is not None), _inspect.getargspec(target))
# /home/admin-u6142160/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/tf_inspect.py:45: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if d.decorator_argspec is not None), _inspect.getargspec(target))
# /home/admin-u6142160/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/tf_inspect.py:45: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if d.decorator_argspec is not None), _inspect.getargspec(target))
# /home/admin-u6142160/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/tf_inspect.py:45: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if d.decorator_argspec is not None), _inspect.getargspec(target))
# /home/admin-u6142160/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/tf_inspect.py:45: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if d.decorator_argspec is not None), _inspect.getargspec(target))
# /home/admin-u6142160/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/tf_inspect.py:45: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if d.decorator_argspec is not None), _inspect.getargspec(target))
# /home/admin-u6142160/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/tf_inspect.py:45: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if d.decorator_argspec is not None), _inspect.getargspec(target))
# /home/admin-u6142160/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/tf_inspect.py:45: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if d.decorator_argspec is not None), _inspect.getargspec(target))
# /home/admin-u6142160/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/tf_inspect.py:45: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if d.decorator_argspec is not None), _inspect.getargspec(target))
# /home/admin-u6142160/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/tf_inspect.py:45: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if d.decorator_argspec is not None), _inspect.getargspec(target))
# /home/admin-u6142160/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/tf_inspect.py:45: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if d.decorator_argspec is not None), _inspect.getargspec(target))
# /home/admin-u6142160/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/tf_inspect.py:45: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if d.decorator_argspec is not None), _inspect.getargspec(target))
# /home/admin-u6142160/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/tf_inspect.py:45: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if d.decorator_argspec is not None), _inspect.getargspec(target))
# /home/admin-u6142160/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/tf_inspect.py:45: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if d.decorator_argspec is not None), _inspect.getargspec(target))
# /home/admin-u6142160/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/tf_inspect.py:45: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if d.decorator_argspec is not None), _inspect.getargspec(target))
# /home/admin-u6142160/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/tf_inspect.py:45: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if d.decorator_argspec is not None), _inspect.getargspec(target))
# /home/admin-u6142160/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/tf_inspect.py:45: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if d.decorator_argspec is not None), _inspect.getargspec(target))
# /home/admin-u6142160/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/tf_inspect.py:45: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if d.decorator_argspec is not None), _inspect.getargspec(target))
# /home/admin-u6142160/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/tf_inspect.py:45: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if d.decorator_argspec is not None), _inspect.getargspec(target))
# /home/admin-u6142160/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/tf_inspect.py:45: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if d.decorator_argspec is not None), _inspect.getargspec(target))
# /home/admin-u6142160/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/tf_inspect.py:45: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if d.decorator_argspec is not None), _inspect.getargspec(target))
# /home/admin-u6142160/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/tf_inspect.py:45: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if d.decorator_argspec is not None), _inspect.getargspec(target))
# /home/admin-u6142160/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/tf_inspect.py:45: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if d.decorator_argspec is not None), _inspect.getargspec(target))
# /home/admin-u6142160/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/tf_inspect.py:45: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if d.decorator_argspec is not None), _inspect.getargspec(target))
# /home/admin-u6142160/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/tf_inspect.py:45: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if d.decorator_argspec is not None), _inspect.getargspec(target))
# /home/admin-u6142160/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/tf_inspect.py:45: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if d.decorator_argspec is not None), _inspect.getargspec(target))
# /home/admin-u6142160/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/tf_inspect.py:45: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if d.decorator_argspec is not None), _inspect.getargspec(target))
# /home/admin-u6142160/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/tf_inspect.py:45: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if d.decorator_argspec is not None), _inspect.getargspec(target))
# /home/admin-u6142160/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/tf_inspect.py:45: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if d.decorator_argspec is not None), _inspect.getargspec(target))
# /home/admin-u6142160/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/tf_inspect.py:45: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if d.decorator_argspec is not None), _inspect.getargspec(target))
# /home/admin-u6142160/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/tf_inspect.py:45: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if d.decorator_argspec is not None), _inspect.getargspec(target))
# /home/admin-u6142160/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/tf_inspect.py:45: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if d.decorator_argspec is not None), _inspect.getargspec(target))
# /home/admin-u6142160/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/tf_inspect.py:45: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if d.decorator_argspec is not None), _inspect.getargspec(target))
# /home/admin-u6142160/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/tf_inspect.py:45: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if d.decorator_argspec is not None), _inspect.getargspec(target))
# /home/admin-u6142160/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/tf_inspect.py:45: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if d.decorator_argspec is not None), _inspect.getargspec(target))
# /home/admin-u6142160/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/tf_inspect.py:45: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if d.decorator_argspec is not None), _inspect.getargspec(target))
# /home/admin-u6142160/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/tf_inspect.py:45: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if d.decorator_argspec is not None), _inspect.getargspec(target))
# /home/admin-u6142160/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/tf_inspect.py:45: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if d.decorator_argspec is not None), _inspect.getargspec(target))
# /home/admin-u6142160/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/tf_inspect.py:45: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if d.decorator_argspec is not None), _inspect.getargspec(target))
# /home/admin-u6142160/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/tf_inspect.py:45: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if d.decorator_argspec is not None), _inspect.getargspec(target))
# /home/admin-u6142160/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/tf_inspect.py:45: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if d.decorator_argspec is not None), _inspect.getargspec(target))
# /home/admin-u6142160/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/tf_inspect.py:45: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if d.decorator_argspec is not None), _inspect.getargspec(target))
# /home/admin-u6142160/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/tf_inspect.py:45: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if d.decorator_argspec is not None), _inspect.getargspec(target))
# /home/admin-u6142160/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/tf_inspect.py:45: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if d.decorator_argspec is not None), _inspect.getargspec(target))
# /home/admin-u6142160/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/tf_inspect.py:45: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if d.decorator_argspec is not None), _inspect.getargspec(target))
# /home/admin-u6142160/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/tf_inspect.py:45: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if d.decorator_argspec is not None), _inspect.getargspec(target))
# /home/admin-u6142160/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/tf_inspect.py:45: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if d.decorator_argspec is not None), _inspect.getargspec(target))
# /home/admin-u6142160/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/tf_inspect.py:45: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if d.decorator_argspec is not None), _inspect.getargspec(target))
# Tensor("down_sampling/pool1/MaxPool:0", shape=(?, 64, 64, 32), dtype=float32)
# Tensor("down_sampling/pool2/MaxPool:0", shape=(?, 32, 32, 64), dtype=float32)
# (4, 4, 64, 64) (3, 3, None, Dimension(96))
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-61de40277181> in <module>()
#      35     net = tf.contrib.layers.conv2d_transpose(inputs=net, num_outputs=None, kernel_size=(3, 3), stride=2,
#      36                                              weights_initializer=get_bilinear_upsample_weights(2, conv_out[2]),
# ---> 37                                              scope='conv3_T')
#      38     print(net)
#      39     with tf.variable_scope('fuse_1'):
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/contrib/framework/python/ops/arg_scope.py in func_with_args(*args, **kwargs)
#     181       current_args = current_scope[key_func].copy()
#     182       current_args.update(kwargs)
# --> 183     return func(*args, **current_args)
#     184
#     185   _add_op(func)
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/contrib/layers/python/layers/layers.py in convolution2d_transpose(inputs, num_outputs, kernel_size, stride, padding, data_format, activation_fn, normalizer_fn, normalizer_params, weights_initializer, weights_regularizer, biases_initializer, biases_regularizer, reuse, variables_collections, outputs_collections, trainable, scope)
#    1311         _scope=sc,
#    1312         _reuse=reuse)
# -> 1313     outputs = layer.apply(inputs)
#    1314
#    1315     # Add variables to collections.
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/layers/base.py in apply(self, inputs, *args, **kwargs)
#     813       Output tensor(s).
#     814     """
# --> 815     return self.__call__(inputs, *args, **kwargs)
#     816
#     817   def _add_inbound_node(self,
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/layers/base.py in __call__(self, inputs, *args, **kwargs)
#     686               pass
#     687           input_shapes = nest.map_structure(lambda x: x.get_shape(), inputs)
# --> 688           self.build(input_shapes)
#     689         try:
#     690           # Note: not all sub-classes of Layer call Layer.__init__ (especially
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/layers/convolutional.py in build(self, input_shape)
#    1623                                     constraint=self.bias_constraint,
#    1624                                     trainable=True,
# -> 1625                                     dtype=self.dtype)
#    1626     else:
#    1627       self.bias = None
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/layers/base.py in add_variable(self, name, shape, dtype, initializer, regularizer, trainable, constraint, partitioner)
#     539                                    constraint=constraint,
#     540                                    trainable=trainable and self.trainable,
# --> 541                                    partitioner=partitioner)
#     542
#     543         if init_graph is not None:  # pylint: disable=protected-access
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/ops/variable_scope.py in get_variable(name, shape, dtype, initializer, regularizer, trainable, collections, caching_device, partitioner, validate_shape, use_resource, custom_getter, constraint)
#    1296       partitioner=partitioner, validate_shape=validate_shape,
#    1297       use_resource=use_resource, custom_getter=custom_getter,
# -> 1298       constraint=constraint)
#    1299 get_variable_or_local_docstring = (
#    1300     """%s
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/ops/variable_scope.py in get_variable(self, var_store, name, shape, dtype, initializer, regularizer, reuse, trainable, collections, caching_device, partitioner, validate_shape, use_resource, custom_getter, constraint)
#    1092           partitioner=partitioner, validate_shape=validate_shape,
#    1093           use_resource=use_resource, custom_getter=custom_getter,
# -> 1094           constraint=constraint)
#    1095
#    1096   def _get_partitioned_variable(self,
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/ops/variable_scope.py in get_variable(self, name, shape, dtype, initializer, regularizer, reuse, trainable, collections, caching_device, partitioner, validate_shape, use_resource, custom_getter, constraint)
#     429       if "constraint" in estimator_util.fn_args(custom_getter):
#     430         custom_getter_kwargs["constraint"] = constraint
# --> 431       return custom_getter(**custom_getter_kwargs)
#     432     else:
#     433       return _true_getter(
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/contrib/layers/python/layers/layers.py in layer_variable_getter(getter, *args, **kwargs)
#    1647   def layer_variable_getter(getter, *args, **kwargs):
#    1648     kwargs['rename'] = rename
# -> 1649     return _model_variable_getter(getter, *args, **kwargs)
#    1650
#    1651   return layer_variable_getter
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/contrib/layers/python/layers/layers.py in _model_variable_getter(getter, name, shape, dtype, initializer, regularizer, trainable, collections, caching_device, partitioner, rename, use_resource, **_)
#    1638       partitioner=partitioner,
#    1639       custom_getter=getter,
# -> 1640       use_resource=use_resource)
#    1641
#    1642
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/contrib/framework/python/ops/arg_scope.py in func_with_args(*args, **kwargs)
#     181       current_args = current_scope[key_func].copy()
#     182       current_args.update(kwargs)
# --> 183     return func(*args, **current_args)
#     184
#     185   _add_op(func)
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/contrib/framework/python/ops/variables.py in model_variable(name, shape, dtype, initializer, regularizer, trainable, collections, caching_device, device, partitioner, custom_getter, use_resource)
#     289                  caching_device=caching_device, device=device,
#     290                  partitioner=partitioner, custom_getter=custom_getter,
# --> 291                  use_resource=use_resource)
#     292   return var
#     293
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/contrib/framework/python/ops/arg_scope.py in func_with_args(*args, **kwargs)
#     181       current_args = current_scope[key_func].copy()
#     182       current_args.update(kwargs)
# --> 183     return func(*args, **current_args)
#     184
#     185   _add_op(func)
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/contrib/framework/python/ops/variables.py in variable(name, shape, dtype, initializer, regularizer, trainable, collections, caching_device, device, partitioner, custom_getter, use_resource)
#     244                   caching_device=caching_device,
#     245                   partitioner=partitioner,
# --> 246                   use_resource=use_resource)
#     247
#     248
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/ops/variable_scope.py in _true_getter(name, shape, dtype, initializer, regularizer, reuse, trainable, collections, caching_device, partitioner, validate_shape, use_resource, constraint)
#     406           trainable=trainable, collections=collections,
#     407           caching_device=caching_device, validate_shape=validate_shape,
# --> 408           use_resource=use_resource, constraint=constraint)
#     409
#     410     if custom_getter is not None:
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/ops/variable_scope.py in _get_single_variable(self, name, shape, dtype, initializer, regularizer, partition_info, reuse, trainable, collections, caching_device, validate_shape, use_resource, constraint)
#     767     if not shape.is_fully_defined() and not initializing_from_value:
#     768       raise ValueError("Shape of a new variable (%s) must be fully defined, "
# --> 769                        "but instead was %s." % (name, shape))
#     770
#     771     # Create the tensor to initialize the variable with default value.
#
# ValueError: Shape of a new variable (up_sampling/conv3_T/biases) must be fully defined, but instead was (?,).

# %% [markdown]
# Fully Connected & Output Layer:

# %%
# Dense Layer 1
net = tf.contrib.layers.fully_connected(inputs=net, num_outputs=layer_out[1], scope='dense1')

# Drop out layer:
net = tf.contrib.layers.dropout(inputs=net, keep_prob=keep_prob, is_training=is_training, scope='drop')

# Dense Layer 2
net = tf.concat( [net, center_crop], 1)
net = tf.contrib.layers.fully_connected(inputs=net, num_outputs=class_output, activation_fn=tf.nn.sigmoid, 
                                        scope='dense2')
net = tf.squeeze(net, name='logits')
# Out:
# /home/admin-u6142160/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/tf_inspect.py:45: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if d.decorator_argspec is not None), _inspect.getargspec(target))

# %% [markdown]
# Cost function & optimizer:

# %%
cross_entropy = tf.reduce_mean(tf.nn.weighted_cross_entropy_with_logits(logits=net, targets=y, 
                                                                        pos_weight=class_weight[1]))

# Ensures that we execute the update_ops before performing the train_step
update_ops = tf.get_collection(tf.GraphKeys.UPDATE_OPS)
with tf.control_dependencies(update_ops):
    train_step = tf.train.AdamOptimizer(learning_rate).minimize(cross_entropy)
# Out:
# /home/admin-u6142160/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/tf_inspect.py:45: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if d.decorator_argspec is not None), _inspect.getargspec(target))
# /home/admin-u6142160/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/tf_inspect.py:45: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if d.decorator_argspec is not None), _inspect.getargspec(target))
# /home/admin-u6142160/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/tf_inspect.py:45: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if d.decorator_argspec is not None), _inspect.getargspec(target))
# /home/admin-u6142160/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/tf_inspect.py:45: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if d.decorator_argspec is not None), _inspect.getargspec(target))
# /home/admin-u6142160/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/tf_inspect.py:45: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if d.decorator_argspec is not None), _inspect.getargspec(target))
# /home/admin-u6142160/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/tf_inspect.py:45: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if d.decorator_argspec is not None), _inspect.getargspec(target))
# /home/admin-u6142160/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/tf_inspect.py:45: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if d.decorator_argspec is not None), _inspect.getargspec(target))
# /home/admin-u6142160/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/tf_inspect.py:45: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if d.decorator_argspec is not None), _inspect.getargspec(target))
# /home/admin-u6142160/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/tf_inspect.py:45: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if d.decorator_argspec is not None), _inspect.getargspec(target))
# /home/admin-u6142160/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/tf_inspect.py:45: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if d.decorator_argspec is not None), _inspect.getargspec(target))
# /home/admin-u6142160/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/tf_inspect.py:45: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if d.decorator_argspec is not None), _inspect.getargspec(target))
# /home/admin-u6142160/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/tf_inspect.py:45: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if d.decorator_argspec is not None), _inspect.getargspec(target))
# /home/admin-u6142160/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/tf_inspect.py:45: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if d.decorator_argspec is not None), _inspect.getargspec(target))
# /home/admin-u6142160/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/tf_inspect.py:45: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if d.decorator_argspec is not None), _inspect.getargspec(target))
# /home/admin-u6142160/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/tf_inspect.py:45: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if d.decorator_argspec is not None), _inspect.getargspec(target))

# %% [markdown]
# Train & monitor:

# %%
saver = tf.train.Saver()

sess = tf.InteractiveSession()
sess.run(tf.global_variables_initializer())

learning_curve = []
iteration = int(Train_Data.size/batch_size) + 1

for epoch_num in range(epoch):
    for iter_num in range(iteration):
        
        batch_x, batch_y = Train_Data.get_patches(batch_size=64)
        batch_x = batch_x.transpose((0, 2, 3, 1))
        train_step.run(feed_dict={x: batch_x, y: batch_y, keep_prob: keep_rate, is_training: True})

    # snap shot
    cur_cost = cross_entropy.eval(feed_dict={x:batch_x, y: batch_y, keep_prob: 1, is_training:False})
    print("cross entropy = ", cur_cost)
    learning_curve.append(cur_cost)
print("finish")

# %%
# plot training curve
plt.figsize=(9,5)
plt.plot(learning_curve)
plt.title('learning_curve')
plt.show()

# %% [markdown]
# ## (Optional) Save the model

# %%
save_path = './Result/motor_trunk_pri_sec_tert/CNN - central pixel/'
model_name = 'motor_trunk_pri_sec_tert'
saver.save(sess, save_path + model_name)

h5f = h5py.File(save_path + "training_info.h5", 'w')

h5f_Index = h5f.create_group("Index")

h5f_Index_Train = h5f_Index.create_group(name='Train')
h5f_Index_Train.create_dataset (name='pos', data=Train_Data.pos_topleft_coord)
h5f_Index_Train.create_dataset (name='neg', data=Train_Data.neg_topleft_coord)

h5f_Index_Test  = h5f_Index.create_group(name='Test')
h5f_Index_Test.create_dataset (name='pos', data=Test_Data.pos_topleft_coord)
h5f_Index_Test.create_dataset (name='neg', data=Test_Data.neg_topleft_coord)

h5f_Norm = h5f.create_group("Norm")
h5f_Norm.create_dataset(name='mu', shape=mu.shape, data=mu)
h5f_Norm.create_dataset(name='sigma', shape=sigma.shape, data=sigma)
h5f.close()

# %% [markdown]
# Evaluate:

# %%
train_metric = Metric()

for img, mask in Train_Data.iterate_data():
    batch = [((img-mu)/sigma).reshape((-1,band,height,width)).transpose((0,2,3,1)).astype(np.float32), 
             np.matrix(mask).astype(int).T]

    # record metric
    pred = prediction.eval(feed_dict={x:batch[0], keep_prob: 1, is_training: False})
    train_metric.accumulate(pred, batch[1])
    
train_metric.print_info()

# %%
test_metric = Metric()

for img, mask in Test_Data.iterate_data():
    batch = [((img-mu)/sigma).reshape((-1,band,height,width)).transpose((0,2,3,1)).astype(np.float32), 
             np.matrix(mask).astype(int).T]
    
    # record metric
    pred = prediction.eval(feed_dict={x:batch[0], keep_prob: 1, is_training: False})
    test_metric.accumulate(pred, batch[1])
    
test_metric.print_info()
